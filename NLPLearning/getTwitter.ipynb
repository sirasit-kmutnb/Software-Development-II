# %%
pip install Tweepy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 337.3 kB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 683.1 kB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 2.7 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 2.7 MB/s eta 0:00:00a 0:00:01
# ...
#
# [notice] A new release of pip available: 22.3 -> 22.3.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 10.7 MB/s eta 0:00:0000:010:01m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 499.4/499.4 kB 18.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 12.2 MB/s eta 0:00:0000:0100:01
# ...
#
# [notice] A new release of pip available: 22.3 -> 22.3.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -U scikit-learn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 3.6 MB/s eta 0:00:0000:0100:010m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.4/28.4 MB 7.2 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 8.0 MB/s eta 0:00:0000:01
# ...
#
# [notice] A new release of pip available: 22.3 -> 22.3.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import tweepy
import pandas as pd

api_key = "SnxucIPt1fg7UUyVOT0T5j0pR"
api_key_secret = "yaToQPv95OA1fiNTHD8drKM8g8rZGM7jSQnPOLoxU3QA9UpaLm"
access_token = "1722424471-Xb0DjPVOqXsLj2sXEYXmU2sqxaDC4B793erGO6J"
access_token_secret = "D2LyXN11zAoZB0M476eb1ZGDM55oRvy4tBWNb8pR4CO0h"
bearer_token = "AAAAAAAAAAAAAAAAAAAAAADnkgEAAAAAgEkTccGImU4WtBjMxyMszSdpswg%3DAFjvso7ju8wFAv1G6cWM2xnOud9F0FaxjHnwpfLbwtXd9Swlxc"
auth = tweepy.OAuthHandler(api_key,api_key_secret)
auth.set_access_token(access_token,access_token_secret)

api = tweepy.API(auth)

query = "#บิ๊กตู่"



df = pd.DataFrame(columns= ["create_at","text","hashtag","re_count","fav_count"])
print(df.columns)
for tweet in tweepy.Cursor(api.search_tweets,q=query,count=10,
result_type="recent",tweet_mode='extended').items():
    create_at = tweet.created_at
    re_count = tweet.retweet_count
    entity_hashtag = tweet.entities.get('hashtags')
    hashtag = ""
    for i in range(0,len(entity_hashtag)):
        hashtag = hashtag +"/"+entity_hashtag[i]["text"]
    try:
        text = tweet.retweeted_status.full_text
        fav_count = tweet.retweeted_status.favorite_count
    except:
        text = tweet.full_text
        fav_count = tweet.favorite_count
    print(text,hashtag)

# df.to_excel("twitterCrawler.xlsx")
# Out:
# Index(['create_at', 'text', 'hashtag', 're_count', 'fav_count'], dtype='object')
# เมื่อ“รทสช.”ไม่แรงตามคาด “บิ๊กตู่”หวังพึ่งบารมี“พี่ใหญ่ 3 ป.”
# https://t.co/pcnqF7Qt57
#
# คอลัมน์ : ล้วง-ลับ-ลึก
# โดย….“แมวสีขาว”
#
# #รวมไทยสร้างชาติ #บิ๊กตู่ #พี่ใหญ่ #พลังประชารัฐ #ล้วงลับลึก #แมวสีขาว #เดอะคีย์นิวส์ #TheKeyNews #TheKeyNews2020 https://t.co/07dfuAAncX /รวมไทยสร้างชาติ/บิ๊กตู่/พี่ใหญ่/พลังประชารัฐ/ล้วงลับลึก/แมวสีขาว/เดอะคีย์นิวส์/TheKeyNews/TheKeyNews2020
# ฝ่ายค้านเตรียมยื่น อภิปราย ดักคอรัฐบาล “อย่ายุบสภาหนี” !! #อย่าหยุบสภา #บิ๊กตู่ #เพื่อไทย #การเมือง #ชลน่าน https://t.co/tSAb0xHBT8 /อย่าหยุบสภา/บิ๊กตู่/เพื่อไทย/การเมือง/ชลน่าน
# ‘บิ๊กตู่’ เตรียมเยี่ยมครอบครัวผู้บาดเจ็บ-เสียชีวิต จากเหตุการณ์เรือหลวงสุโขทัยอับปาง
#
# Click on Clear &gt;&gt; https://t.co/15mzOYQ3CA
#
# #THESTATESTIMES
# #NewsFeed
# #บิ๊กตู่
# #ประยุทธ์จันทร์โอชา
# #เรือหลวงอับปาง /THESTATESTIMES/NewsFeed/บิ๊กตู่/ประยุทธ์จันทร์โอชา/เรือหลวงอับปาง
# ...
