# %%
import pythainlp
pythainlp.__version__
# Out:
# '3.1.1'

# %%
pythainlp.thai_characters
# Out:
# 'กขฃคฅฆงจฉชซฌญฎฏฐฑฒณดตถทธนบปผฝพฟภมยรลวศษสหฬอฮฤฦะัาำิีึืุูเแโใไๅํ็่้๊๋ฯฺๆ์ํ๎๏๚๛๐๑๒๓๔๕๖๗๘๙฿'

# %%
print(pythainlp.util.isthai("Aกด"))
# Out:
# False

# %%
from pythainlp.tokenize.multi_cut import find_all_segment
find_all_segment("ฉันชอบไปเที่ยวน้ำตกที่นครศรีธรรมราช")[-1].split('|')
# Out:
# ['ฉัน', 'ชอบ', 'ไปเที่ยว', 'น้ำตก', 'ที่', 'นครศรีธรรมราช', '']

# %%
from pythainlp import correct

correct("สวัสดี")
# Out:
# 'สวัสดี'

# %%
from pythainlp.tokenize import word_tokenize

text = "สวัสดีครับ ผมเป็นนักศึกษา"

word_tokenize(text, engine="newmm")
# output: ['โอเค', 'บ่', 'พวกเรา', 'รัก', 'ภาษา', 'บ้านเกิด']
# Out:
# ['สวัสดี', 'ครับ', ' ', 'ผม', 'เป็น', 'นักศึกษา']

# %%
import openpyxl

book = openpyxl.load_workbook("positiveTweets_1.xlsx")
sheet = book.active
print(sheet.max_row)

# for i in range(0, sheet.max_row):
#     for col in sheet.iter_cols(1, sheet.max_column):
#         print(col[i].value, end="\t\t")
#     print('')
# Out:
# 1001

# %%
from pythainlp.corpus import thai_stopwords
stop_word = list(thai_stopwords())
print(stop_word)
# Out:
# ['ฝ่าย', 'เพียงแค่', 'เช่นนั้นเอง', 'แสดง', 'เป็นเพราะว่า', 'มัก', 'สูงๆ', 'ซึ่งๆ', 'เมื่อวาน', 'ประการหนึ่ง', 'ตั้ง', 'ช่วงที่', 'ง่าย', 'ขาด', 'เพื่อ', 'นู่น', 'ดังกับ', 'ยอมรับ', 'ละ', 'เมื่อเช้า', 'สืบเนื่อง', 'วันนั้น', 'ปรับ', 'คราว', 'เพื่อให้', 'เฉพาะ', 'กว้างขวาง', 'จะ', 'นั้นไว', 'เกือบ', 'สําหรับ', 'ภายนอก', 'เท่าที่', 'เพียงแต่', 'มั้ยนั่น', 'รวมๆ', 'มีแต่', 'เมื่อครั้งก่อน', 'ให้มา', 'ถือว่า', 'ซึ่งกันและกัน', 'ข้าฯ', 'ที', 'ทุก', 'ใหม่ๆ', 'บางครั้ง', 'ครั้งก่อน', 'นับจากนี้', 'เช่น', 'ทีใด', 'ฝ่ายใด', 'บอกว่า', 'ด้วยประการฉะนี้', 'น้อย', 'อันได้แก่', 'ตลอดศก', 'สั้น', 'คล้ายกัน', 'อย่างๆ', 'ที่แท้จริง', 'ถึงแม้ว่า', 'ทุกหน', 'ร่วมกัน', 'ทั้งนั้นด้วย', 'ครับ', 'ตามๆ', 'จวนจะ', 'ตามแต่', 'นั่นไง', 'ออก', 'แม้แต่', 'ช่วงแรก', 'นับแต่นั้น', 'เท่าใด', 'ด้วยเหตุนี้', 'เช่นเดียวกับ', 'กันนะ', 'สิ่ง', 'ระยะ',